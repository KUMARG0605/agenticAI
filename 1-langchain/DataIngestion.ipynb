# %%
from langchain_community.document_loaders import TextLoader

docs = TextLoader("Docker.txt").load()

for doc in docs:
    for line in doc.page_content.split("\n"):
        print(line)
# Out:
# ###############################################################
# Docker --- containarization tool (to deploy the application)
#
#
#
#
# Before running appplication  must specifies dependencies -->
# 																								CPU-4
# 																								RAM-16GB
# 																								HDD-100GB
# 								using resources well
#
# 								totally we have  HDD 500GB --- divide among the 4 application
#
#
# 								containers 1 				                             CPU-4
# 																								RAM-16GB
# 																								HDD-100GB
#
# 								containers 2 											CPU-4
# 																								RAM-16GB
# 																								HDD-100GB
#
# 								containers 3											CPU-4
# 																								RAM-16GB
# 																								HDD-100GB
#
# 								to run 10 applications we requires 10 physical servers but using containarization we can efficiently use the physical VMs (host machine)
# 								manages project cost low
#
#
# 1. Container Management
#
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
da=PyPDFLoader("Generative AI Brochure.pdf").load()
for _ in da:
    for line in _.page_content.split("\n"):
        print(line)
# Out:
# GENERATIVE AI
# CERTIFICATION COURSE
# ADVANCED
# Embrace the thrilling future of creativity! Unleash limitless potential
# with Generative AI, where your imagination collides with
# groundbreaking innovation in extraordinary ways!
# I
# T
# &
# IIT Guwahati
# E C
# Duration 6 Months
# /uni0041/uni0062/uni006F/uni0075/uni0074
# /uni0049/uni0049/uni0054/uni0020/uni0047/uni0075/uni0077/uni0061/uni0068/uni0061/uni0074/uni0069
# Page No 1
# 
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
    web_paths=["https://www.geeksforgeeks.org/artificial-intelligence/large-language-model-llm/","https://chatgpt.com/c/6968fdec-3d58-832b-bde1-6500ecc862ea"]
)

data = loader.load()

print(data[1].page_content[:])
# Out:
# Enable JavaScript and cookies to continue

# %%
from langchain_community.document_loaders import WebBaseLoader
import bs4

loader = WebBaseLoader(
    web_paths=["https://www.geeksforgeeks.org/artificial-intelligence/large-language-model-llm/",
    "https://chatgpt.com/c/6968fdec-3d58-832b-bde1-6500ecc862ea"],

    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=["post-title", "post-content", "post-header"]
        )
    )
)

docs = loader.load()

print(docs[0].page_content)
